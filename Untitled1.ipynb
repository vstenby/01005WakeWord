# %% [markdown]
# # Loading in the results

# %%
import pandas as pd
import numpy as np
import IPython.display as ipd
results = pd.read_csv('results.csv')

# %%
TP = results.loc[(results['target'] == 1)&(results['prediction'] == 1)]
FP = results.loc[(results['target'] == 0)&(results['prediction'] == 1)]
FN = results.loc[(results['target'] == 1)&(results['prediction'] == 0)]
TN = results.loc[(results['target'] == 0)&(results['prediction'] == 0)]

# %% [markdown]
# # Let us have a look at the FP.

# %%
for path in FP['path'].tolist():
    print(path)
    ipd.display(ipd.Audio(path))
# Out:
# ./export/test/0_481y9w9f_t2526.9192175430567_c0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ./export/test/0_6xvr5trs_t182.3988281727009_c0.wav
# ./export/test/0_z7rjz126_t1195.436813080262_c0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
p = np.load('0_0c7wcwij.npy')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.plot(p[1,:])
